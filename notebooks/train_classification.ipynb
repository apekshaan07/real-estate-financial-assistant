# %% [markdown]
# # Bank Marketing Classification Training
#
# Logistic Regression classifier trained on the UCI Bank Marketing dataset.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

from training.train_classification import main

main()
